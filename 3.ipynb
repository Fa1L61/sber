# %% [markdown]
# ![image.png](attachment:ae4d38da-4f72-4df9-9910-ef9d04a3e149.png)

# %%
def func(arr):
    arr = list(arr)
    print(list(arr))
    return int(''.join(sorted(arr)[::-1]))

arr = map(str, input('Enter the number of lines').split())
func(arr)
# Out:
# Enter the number of lines 11 234 005 89
# ['11', '234', '005', '89']
# 8923411005

# %%
# Out:
# []

# %%
# Out:
# ['arr', 'barr', 'car']
