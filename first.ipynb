# %% [markdown]
# ![image.png](attachment:56a687fc-834e-4fd6-90a0-17ad542bbfdf.png)

# %%
import re

def correct_num(str):
    temp = re.findall(r'\b\d{2,4}\\\d{2,5}\b', str)
    for i in range(len(temp)):
        n_str = temp[i].split("\\")
        print(n_str[0].zfill(4) + chr(92) + n_str[1].zfill(5))

# %%
str1 = input("Enter the str")
correct_num(str1)
# Out:
# Enter the str 1\1 1\12 1\123 1\1234 1\12345 1\123456 12\1 12\12 12\123 12\1234 12\12345 12\123456 123\1 123\12 123\123 123\1234 123\12345 123\123456 1234\1 1234\12 1234\123 1234\1234 1234\12345 1234\123456 12345\1 12345\12 12345\123 12345\1234 12345\12345 12345\123456 123456\1 123456\12 123456\123 123456\1234 123456\12345 123456\123456
# 0012\00012
# 0012\00123
# 0012\01234
# 0012\12345
# 0123\00012
# 0123\00123
# 0123\01234
# 0123\12345
# 1234\00012
# 1234\00123
# 1234\01234
# 1234\12345
